# %% [markdown]
# #EffectorP module
#
#
# > This module use EffectorP package to predict whether SSP is effector if so its subcellular localization in host.

# %% [markdown]
# **Installation**

# %%
# !git clone https://github.com/JanaSperschneider/EffectorP-3.0.git
# %cd EffectorP-3.0

# !pip install biopython pandas
from google.colab import files
uploaded = files.upload()
# Out:
# Cloning into 'EffectorP-3.0'...
# remote: Enumerating objects: 753, done.
# remote: Total 753 (delta 0), reused 0 (delta 0), pack-reused 753 (from 2)
# Receiving objects: 100% (753/753), 69.16 MiB | 20.22 MiB/s, done.
# Resolving deltas: 100% (355/355), done.
# /content/EffectorP-3.0
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 50.8 MB/s eta 0:00:00
# ...
#      <input type="file" id="files-c1c9557f-9c8d-4106-9d08-768518b40d16" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c1c9557f-9c8d-4106-9d08-768518b40d16">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# ...

# %%
# %cd /content/EffectorP-3.0
# !unzip -q weka-3-8-4.zip
# Out:
# /content/EffectorP-3.0

# %%
fasta_file = list(uploaded.keys())[0]
print("Uploaded file:", fasta_file)


# !python EffectorP.py -i $fasta_file -o effectorp_output.txt
# Out:
# Uploaded file: uniprotkb_accession_K2QS10_2026_05_07.fasta
# -----------------
#
# EffectorP 3.0 is running for 1 proteins given in FASTA file uniprotkb_accession_K2QS10_2026_05_07.fasta
#
# Ensemble classification
# 25 percent done...
# 50 percent done...
# 75 percent done...
# All done.
#
# # Identifier                                                                                                            	Cytoplasmic effector	Apoplastic effector 	Non-effector        	Prediction
# tr|K2QS10|K2QS10_MACPH Cell wall protein PhiA OS=Macrophomina phaseolina (strain MS6) OX=1126212 GN=MPH_10215 PE=4 SV=1 	-                   	Y (0.63)           	-                   	Apoplastic effector
#
# EffectorP results were saved to output file: effectorp_output.txt
# -----------------
# 1 proteins were provided as input in the following file: uniprotkb_accession_K2QS10_2026_05_07.fasta
# -----------------
# Number of predicted effectors: 1
# Number of predicted cytoplasmic effectors: 0
# ...
